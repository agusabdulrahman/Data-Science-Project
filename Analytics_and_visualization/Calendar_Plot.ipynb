# %%
# !pip install plotly-calplot pandas
# !pip install plotly-calplot

# %%
import pandas as pd

# Example data
data = {
    "date": pd.date_range(start="2023-01-01", end="2023-12-31", freq="D"),
    "value": [i % 10 + 1 for i in range(365)]  # Simulated data
}

df = pd.DataFrame(data)
print(df.head())
# Out:
#         date  value
# 0 2023-01-01      1
# 1 2023-01-02      2
# 2 2023-01-03      3
# 3 2023-01-04      4
# 4 2023-01-05      5

# %%
from plotly_calplot import calplot

# Create the calendar plot
fig = calplot(
    df,
    x="date",       # Column with date information
    y="value",      # Column with values
    years_title="Activity Heatmap",  # Title of the calendar
    colorscale="Blues",  # Color scale for the heatmap
    showscale=True   # Show color bar
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotly_calplot import calplot

# Create the calendar plot
fig = calplot(
    df,
    x="date",
    y="value",
    years_title="Customized Calendar Plot",
    colorscale="Viridis"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = calplot(
    df,
    x="date",
    y="value",
    years_title="Customized Calendar Plot",
    dark_theme=True

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
